# %% [markdown]
# # Implementing a Multilayer Perceptron (MNIST)

# %% [markdown]
# ## 2) Loading the dataset

# %% [markdown]
# - MNIST website: http://yann.lecun.com/exdb/mnist/

# %%
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

train_dataset = datasets.MNIST(
    root="../data", train=True, transform=transforms.ToTensor(), download=True
)

test_dataset = datasets.MNIST(
    root="../data", train=False, transform=transforms.ToTensor()
)

# %%
len(train_dataset)
# Out:
# 60000

# %%
len(test_dataset)
# Out:
# 10000

# %% [markdown]
# ### Create a validation set

# %%
import torch
from torch.utils.data.dataset import random_split

torch.manual_seed(1)
train_dataset, val_dataset = random_split(train_dataset, lengths=[55000, 5000])

# %%
train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=64,
    shuffle=True,
)

val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=64,
    shuffle=False,
)

test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=64,
    shuffle=False,
)

# %% [markdown]
# ## 3) Implementing the model

# %%
import torch

class PyTorchMLP(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super().__init__()

        self.all_layers = torch.nn.Sequential(
            # 1st hidden layer
            torch.nn.Linear(num_features, 32),
            torch.nn.ReLU(),
            # output layer
            torch.nn.Linear(32, num_classes),
        )

    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        logits = self.all_layers(x)
        return logits

# %% [markdown]
# ## 4) The training loop

# %%
def compute_accuracy(model, dataloader):
    model = model.eval()

    correct = 0.0
    total_examples = 0

    for idx, (features, labels) in enumerate(dataloader):
        with torch.no_grad():
            logits = model(features)

        predictions = torch.argmax(logits, dim=1)

        compare = labels == predictions
        correct += torch.sum(compare)
        total_examples += len(compare)

    return correct / total_examples

# %%
import torch.nn.functional as F

torch.manual_seed(1)
model = PyTorchMLP(num_features=784, num_classes=10)

optimizer = torch.optim.SGD(model.parameters(), lr=0.05)

num_epochs = 20

loss_list = []
train_acc_list, val_acc_list = [], []
for epoch in range(num_epochs):

    model = model.train()
    for batch_idx, (features, labels) in enumerate(train_loader):
        logits = model(features)

        loss = F.cross_entropy(logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if not batch_idx % 250:
            ### LOGGING
            print(
                f"Epoch: {epoch+1:03d}/{num_epochs:03d}"
                f" | Batch {batch_idx:03d}/{len(train_loader):03d}"
                f" | Train Loss: {loss:.2f}"
            )
        loss_list.append(loss.item())

    train_acc = compute_accuracy(model, train_loader)
    val_acc = compute_accuracy(model, val_loader)
    print(f"Train Acc {train_acc*100:.2f}% | Val Acc {val_acc*100:.2f}%")
    train_acc_list.append(train_acc)
    val_acc_list.append(val_acc)
# Out:
# Epoch: 001/020 | Batch 000/860 | Train Loss: 2.32
# Epoch: 001/020 | Batch 250/860 | Train Loss: 0.57
# Epoch: 001/020 | Batch 500/860 | Train Loss: 0.35
# Epoch: 001/020 | Batch 750/860 | Train Loss: 0.40
# Train Acc 90.35% | Val Acc 90.46%
# Epoch: 002/020 | Batch 000/860 | Train Loss: 0.51
# Epoch: 002/020 | Batch 250/860 | Train Loss: 0.39
# Epoch: 002/020 | Batch 500/860 | Train Loss: 0.41
# Epoch: 002/020 | Batch 750/860 | Train Loss: 0.47
# Train Acc 91.65% | Val Acc 91.48%
# Epoch: 003/020 | Batch 000/860 | Train Loss: 0.21
# Epoch: 003/020 | Batch 250/860 | Train Loss: 0.15
# Epoch: 003/020 | Batch 500/860 | Train Loss: 0.20
# Epoch: 003/020 | Batch 750/860 | Train Loss: 0.38
# Train Acc 93.05% | Val Acc 92.72%
# Epoch: 004/020 | Batch 000/860 | Train Loss: 0.10
# Epoch: 004/020 | Batch 250/860 | Train Loss: 0.30
# Epoch: 004/020 | Batch 500/860 | Train Loss: 0.25
# Epoch: 004/020 | Batch 750/860 | Train Loss: 0.56
# Train Acc 93.68% | Val Acc 93.26%
# Epoch: 005/020 | Batch 000/860 | Train Loss: 0.17
# Epoch: 005/020 | Batch 250/860 | Train Loss: 0.21
# Epoch: 005/020 | Batch 500/860 | Train Loss: 0.05
# Epoch: 005/020 | Batch 750/860 | Train Loss: 0.27
# Train Acc 94.57% | Val Acc 93.98%
# Epoch: 006/020 | Batch 000/860 | Train Loss: 0.10
# Epoch: 006/020 | Batch 250/860 | Train Loss: 0.28
# Epoch: 006/020 | Batch 500/860 | Train Loss: 0.26
# Epoch: 006/020 | Batch 750/860 | Train Loss: 0.41
# Train Acc 95.01% | Val Acc 94.10%
# Epoch: 007/020 | Batch 000/860 | Train Loss: 0.14
# Epoch: 007/020 | Batch 250/860 | Train Loss: 0.32
# Epoch: 007/020 | Batch 500/860 | Train Loss: 0.13
# Epoch: 007/020 | Batch 750/860 | Train Loss: 0.24
# Train Acc 95.23% | Val Acc 94.08%
# Epoch: 008/020 | Batch 000/860 | Train Loss: 0.12
# Epoch: 008/020 | Batch 250/860 | Train Loss: 0.11
# Epoch: 008/020 | Batch 500/860 | Train Loss: 0.22
# Epoch: 008/020 | Batch 750/860 | Train Loss: 0.18
# Train Acc 95.80% | Val Acc 94.72%
# Epoch: 009/020 | Batch 000/860 | Train Loss: 0.38
# Epoch: 009/020 | Batch 250/860 | Train Loss: 0.15
# Epoch: 009/020 | Batch 500/860 | Train Loss: 0.09
# Epoch: 009/020 | Batch 750/860 | Train Loss: 0.07
# Train Acc 96.11% | Val Acc 94.86%
# Epoch: 010/020 | Batch 000/860 | Train Loss: 0.08
# Epoch: 010/020 | Batch 250/860 | Train Loss: 0.36
# Epoch: 010/020 | Batch 500/860 | Train Loss: 0.09
# Epoch: 010/020 | Batch 750/860 | Train Loss: 0.26
# Train Acc 96.30% | Val Acc 95.12%
# Epoch: 011/020 | Batch 000/860 | Train Loss: 0.14
# Epoch: 011/020 | Batch 250/860 | Train Loss: 0.24
# Epoch: 011/020 | Batch 500/860 | Train Loss: 0.13
# Epoch: 011/020 | Batch 750/860 | Train Loss: 0.14
# Train Acc 96.50% | Val Acc 95.10%
# Epoch: 012/020 | Batch 000/860 | Train Loss: 0.29
# Epoch: 012/020 | Batch 250/860 | Train Loss: 0.05
# Epoch: 012/020 | Batch 500/860 | Train Loss: 0.16
# Epoch: 012/020 | Batch 750/860 | Train Loss: 0.10
# Train Acc 96.65% | Val Acc 95.36%
# Epoch: 013/020 | Batch 000/860 | Train Loss: 0.05
# Epoch: 013/020 | Batch 250/860 | Train Loss: 0.05
# Epoch: 013/020 | Batch 500/860 | Train Loss: 0.04
# Epoch: 013/020 | Batch 750/860 | Train Loss: 0.06
# Train Acc 96.85% | Val Acc 95.28%
# Epoch: 014/020 | Batch 000/860 | Train Loss: 0.06
# Epoch: 014/020 | Batch 250/860 | Train Loss: 0.06
# Epoch: 014/020 | Batch 500/860 | Train Loss: 0.05
# Epoch: 014/020 | Batch 750/860 | Train Loss: 0.21
# Train Acc 96.77% | Val Acc 95.36%
# Epoch: 015/020 | Batch 000/860 | Train Loss: 0.06
# Epoch: 015/020 | Batch 250/860 | Train Loss: 0.04
# Epoch: 015/020 | Batch 500/860 | Train Loss: 0.16
# Epoch: 015/020 | Batch 750/860 | Train Loss: 0.08
# Train Acc 97.14% | Val Acc 95.66%
# Epoch: 016/020 | Batch 000/860 | Train Loss: 0.08
# Epoch: 016/020 | Batch 250/860 | Train Loss: 0.18
# Epoch: 016/020 | Batch 500/860 | Train Loss: 0.05
# Epoch: 016/020 | Batch 750/860 | Train Loss: 0.06
# Train Acc 97.21% | Val Acc 95.62%
# Epoch: 017/020 | Batch 000/860 | Train Loss: 0.15
# Epoch: 017/020 | Batch 250/860 | Train Loss: 0.03
# Epoch: 017/020 | Batch 500/860 | Train Loss: 0.05
# Epoch: 017/020 | Batch 750/860 | Train Loss: 0.21
# Train Acc 97.31% | Val Acc 95.82%
# Epoch: 018/020 | Batch 000/860 | Train Loss: 0.07
# Epoch: 018/020 | Batch 250/860 | Train Loss: 0.05
# Epoch: 018/020 | Batch 500/860 | Train Loss: 0.16
# Epoch: 018/020 | Batch 750/860 | Train Loss: 0.03
# Train Acc 97.37% | Val Acc 95.84%
# Epoch: 019/020 | Batch 000/860 | Train Loss: 0.08
# Epoch: 019/020 | Batch 250/860 | Train Loss: 0.08
# Epoch: 019/020 | Batch 500/860 | Train Loss: 0.06
# Epoch: 019/020 | Batch 750/860 | Train Loss: 0.05
# Train Acc 97.38% | Val Acc 95.88%
# Epoch: 020/020 | Batch 000/860 | Train Loss: 0.08
# Epoch: 020/020 | Batch 250/860 | Train Loss: 0.14
# Epoch: 020/020 | Batch 500/860 | Train Loss: 0.08
# Epoch: 020/020 | Batch 750/860 | Train Loss: 0.04
# Train Acc 97.65% | Val Acc 95.82%

# %% [markdown]
# ## 7) Evaluating the results

# %% [markdown]
# Previous results with 2 hidden layers:

# %%
# train_acc = compute_accuracy(model, train_loader)
# val_acc = compute_accuracy(model, val_loader)
# test_acc = compute_accuracy(model, test_loader)

# print(f"Train Acc {train_acc*100:.2f}%")
# print(f"Val Acc {val_acc*100:.2f}%")
# print(f"Test Acc {test_acc*100:.2f}%")

# %% [markdown]
# Only one hidden layer, much less weights, better performance:

# %%
train_acc = compute_accuracy(model, train_loader)
val_acc = compute_accuracy(model, val_loader)
test_acc = compute_accuracy(model, test_loader)

print(f"Train Acc {train_acc*100:.2f}%")
print(f"Val Acc {val_acc*100:.2f}%")
print(f"Test Acc {test_acc*100:.2f}%")
# Out:
# Train Acc 97.65%
# Val Acc 95.82%
# Test Acc 96.73%

# %%
from helper_plotting import plot_training_loss

plot_training_loss(minibatch_loss_list=loss_list,
                   num_epochs=num_epochs,
                   iter_per_epoch=len(loss_list)//num_epochs)

# %%
from helper_plotting import plot_accuracy

plot_accuracy(train_acc_list=train_acc_list, valid_acc_list=val_acc_list)

# %% [markdown]
# Model started overfiting.
