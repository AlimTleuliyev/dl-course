# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('perceptron_toydata-truncated.txt', sep = '\t')
df.head()
# Out:
#      x1    x2  label
# 0  0.77 -1.14      0
# 1 -0.33  1.44      0
# 2  0.91 -3.07      0
# 3 -0.37 -1.91      0
# 4 -0.63 -1.53      0

# %%
X_train = df[['x1', 'x2']].values
y_train = df['label'].values

# %% [markdown]
# ### 2) Data Visualization

# %%
plt.figure(figsize=(4, 4))
plt.plot(
    X_train[y_train == 0, 0],
    X_train[y_train == 0, 1],
    marker = 'D',
    markersize = 10,
    linestyle = '',
    label = 'Class 0'
)

plt.plot(
    X_train[y_train == 1, 0],
    X_train[y_train == 1, 1],
    marker = '^',
    markersize = 13,
    linestyle = '',
    label = 'Class 1'
)

plt.legend(loc = 'upper left')

plt.xlim([-5,5])
plt.ylim([-5,5])

plt.xlabel('Feature $x_1$')
plt.ylabel('Feature $x_2$')

plt.grid()
plt.show()

# %% [markdown]
# ### 3) Original perceptron from last time

# %%
class Perceptron:
    def __init__(self, num_features):
        self.num_features = num_features
        self.weights = [0.0 for _ in range(num_features)]
        self.bias = 0.0

    def forward(self, x):
        weighted_sum_z = self.bias
        for i, _ in enumerate(self.weights):
            weighted_sum_z += x[i] * self.weights[i]
        
        if weighted_sum_z > 0:
            return 1
        else:
            return 0
    
    def update(self, x, true_y):
        prediction = self.forward(x)
        error = true_y - prediction

        # update
        self.bias += error
        for i, _ in enumerate(self.weights):
            self.weights[i] += error * x[i]
        
        return error
    
    def train(self, X_train, y_train, epochs):
        if X_train.shape[1] != self.num_features:
            raise ValueError('Number of features does not match')
        
        for epoch in range(epochs):
            epoch_error = 0.0

            for x, y_true in zip(X_train, y_train):
                error = self.update(x, y_true)
                epoch_error += abs(error)
            
            print(f'Epoch {epoch + 1}: error = {epoch_error}')
            
            if epoch_error == 0:
                print('\tEarly stopping')
                break

    def score(self, X, y):
        num_correct = 0
        for x, y in zip(X, y):
            prediction = self.forward(x)
            num_correct += int(prediction == y)
        
        return num_correct / len(X)

# %% [markdown]
# ### 4) Excercise 1
# #### Modifying train function: Add early-stopping to make the Perceptron more efficient.

# %%
class Perceptron:
    def __init__(self, num_features):
        self.num_features = num_features
        self.weights = [0.0 for _ in range(num_features)]
        self.bias = 0.0

    def forward(self, x):
        weighted_sum_z = self.bias
        for i, _ in enumerate(self.weights):
            weighted_sum_z += x[i] * self.weights[i]
        
        if weighted_sum_z > 0:
            return 1
        else:
            return 0
    
    def update(self, x, true_y):
        prediction = self.forward(x)
        error = true_y - prediction

        # update
        self.bias += error
        for i, _ in enumerate(self.weights):
            self.weights[i] += error * x[i]
        
        return error
    
    def train(self, X_train, y_train, epochs):
        if X_train.shape[1] != self.num_features:
            raise ValueError('Number of features does not match')
        
        for epoch in range(epochs):
            epoch_error = 0.0

            for x, y_true in zip(X_train, y_train):
                error = self.update(x, y_true)
                epoch_error += abs(error)
            
            print(f'Epoch {epoch + 1}: error = {epoch_error}')
            
            if epoch_error == 0:
                print('\tEarly stopping')
                break

    def score(self, X, y):
        num_correct = 0
        for x, y in zip(X, y):
            prediction = self.forward(x)
            num_correct += int(prediction == y)
        
        return num_correct / len(X)

# %%
ppn = Perceptron(num_features = 2)
ppn.train(X_train, y_train, epochs = 100)
# Out:
# Epoch 1: error = 1.0
# Epoch 2: error = 3.0
# Epoch 3: error = 1.0
# Epoch 4: error = 0.0
# 	Early stopping

# %%
ppn.score(X_train, y_train)
# Out:
# 1.0

# %%
def plot_boundary(model):

    w1, w2 = model.weights[0], model.weights[1]
    b = model.bias

    x1_min = -20
    x2_min = (-(w1 * x1_min) - b) / w2

    x1_max = 20
    x2_max = (-(w1 * x1_max) - b) / w2

    return x1_min, x1_max, x2_min, x2_max

# %%
x1_min, x1_max, x2_min, x2_max = plot_boundary(ppn)

plt.figure(figsize=(4, 4))
plt.plot(
    X_train[y_train == 0, 0],
    X_train[y_train == 0, 1],
    marker="D",
    markersize=10,
    linestyle="",
    label="Class 0",
)

plt.plot(
    X_train[y_train == 1, 0],
    X_train[y_train == 1, 1],
    marker="^",
    markersize=13,
    linestyle="",
    label="Class 1",
)
plt.plot([x1_min, x1_max], [x2_min, x2_max], color="k")

plt.legend(loc=2)

plt.xlim([-5, 5])
plt.ylim([-5, 5])

plt.xlabel("Feature $x_1$", fontsize=12)
plt.ylabel("Feature $x_2$", fontsize=12)

plt.grid()
plt.show()

# %% [markdown]
# ### 5) Excercise 2
# #### Initialize the model parameters with small random numbers instead of 0’s

# %%
import random

class Perceptron:
    def __init__(self, num_features):
        random.seed(123)
        self.num_features = num_features
        self.weights = [random.uniform(-0.5, 0.5) for _ in range(num_features)]
        self.bias = random.uniform(-0.5, 0.5)

    def forward(self, x):
        weighted_sum_z = self.bias
        for i, _ in enumerate(self.weights):
            weighted_sum_z += x[i] * self.weights[i]
        
        if weighted_sum_z > 0:
            return 1
        else:
            return 0
    
    def update(self, x, true_y):
        prediction = self.forward(x)
        error = true_y - prediction

        # update
        self.bias += error
        for i, _ in enumerate(self.weights):
            self.weights[i] += error * x[i]
        
        return error
    
    def train(self, X_train, y_train, epochs):
        if X_train.shape[1] != self.num_features:
            raise ValueError('Number of features does not match')
        
        for epoch in range(epochs):
            epoch_error = 0.0

            for x, y_true in zip(X_train, y_train):
                error = self.update(x, y_true)
                epoch_error += abs(error)
            
            print(f'Epoch {epoch + 1}: error = {epoch_error}')
            
            if epoch_error == 0:
                print('\tEarly stopping')
                break

    def score(self, X, y):
        num_correct = 0
        for x, y in zip(X, y):
            prediction = self.forward(x)
            num_correct += int(prediction == y)
        
        return num_correct / len(X)

# %%
ppn = Perceptron(2)

# %%
ppn.train(X_train, y_train, epochs = 10)
# Out:
# Epoch 1: error = 4.0
# Epoch 2: error = 1.0
# Epoch 3: error = 0.0
# 	Early stopping

# %% [markdown]
# As we can see our model trained faster and with less epochs. This is because we are not initializing the weights to 0, but to small random numbers. This way, the model can learn faster and more efficiently.

# %%
ppn.score(X_train, y_train)
# Out:
# 1.0

# %%
x1_min, x1_max, x2_min, x2_max = plot_boundary(ppn)

plt.figure(figsize=(4, 4))
plt.plot(
    X_train[y_train == 0, 0],
    X_train[y_train == 0, 1],
    marker="D",
    markersize=10,
    linestyle="",
    label="Class 0",
)

plt.plot(
    X_train[y_train == 1, 0],
    X_train[y_train == 1, 1],
    marker="^",
    markersize=13,
    linestyle="",
    label="Class 1",
)
plt.plot([x1_min, x1_max], [x2_min, x2_max], color="k")

plt.legend(loc=2)

plt.xlim([-5, 5])
plt.ylim([-5, 5])

plt.xlabel("Feature $x_1$", fontsize=12)
plt.ylabel("Feature $x_2$", fontsize=12)

plt.grid()
plt.show()

# %% [markdown]
# ### 6) Excercise 3
# #### Use a learning rate for updating the weights and bias unit

# %%
import random

class Perceptron:
    def __init__(self, num_features, alpha = 1.0):
        random.seed(123)
        self.num_features = num_features
        self.alpha = alpha
        self.weights = [random.uniform(-0.5, 0.5) for _ in range(num_features)]
        self.bias = random.uniform(-0.5, 0.5)

    def forward(self, x):
        weighted_sum_z = self.bias
        for i, _ in enumerate(self.weights):
            weighted_sum_z += x[i] * self.weights[i]
        
        if weighted_sum_z > 0:
            return 1
        else:
            return 0
    
    def update(self, x, true_y):
        prediction = self.forward(x)
        error = true_y - prediction

        # update
        self.bias += error
        for i, _ in enumerate(self.weights):
            self.weights[i] += self.alpha * error * x[i]
        
        return error
    
    def train(self, X_train, y_train, epochs, verbose = True):
        if X_train.shape[1] != self.num_features:
            raise ValueError('Number of features does not match')
        
        for epoch in range(epochs):
            epoch_error = 0.0

            for x, y_true in zip(X_train, y_train):
                error = self.update(x, y_true)
                epoch_error += abs(error)
            
            if verbose:
                print(f'Epoch {epoch + 1}: error = {epoch_error}')
                print(f'\tWeights = {self.weights}, bias = {self.bias}')
            
            if epoch_error == 0:
                print(f'\tEarly stopping at epoch {epoch + 1}')
                return epoch + 1
        
        return epochs

    def score(self, X, y):
        num_correct = 0
        for x, y in zip(X, y):
            prediction = self.forward(x)
            num_correct += int(prediction == y)
        
        return num_correct / len(X)

# %%
num_of_epochs = []
alphas = np.arange(0.001, 5, 0.001)
for alpha in alphas:
    print('Training with alpha =', alpha)
    ppn = Perceptron(2, alpha = alpha)
    epochs = ppn.train(X_train, y_train, epochs = 10000, verbose=False)
    print(f'\tAccuracy = {ppn.score(X_train, y_train)}\n')
    num_of_epochs.append(epochs)
# Out:
# Training with alpha = 0.001
# 	Early stopping at epoch 123
# 	Accuracy = 1.0
#
# Training with alpha = 0.002
# 	Early stopping at epoch 62
# 	Accuracy = 1.0
#
# Training with alpha = 0.003
# 	Early stopping at epoch 43
# 	Accuracy = 1.0
#
# Training with alpha = 0.004
# 	Early stopping at epoch 32
# 	Accuracy = 1.0
#
# Training with alpha = 0.005
# 	Early stopping at epoch 25
# 	Accuracy = 1.0
#
# Training with alpha = 0.006
# 	Early stopping at epoch 22
# 	Accuracy = 1.0
#
# Training with alpha = 0.007
# 	Early stopping at epoch 20
# 	Accuracy = 1.0
#
# Training with alpha = 0.008
# 	Early stopping at epoch 17
# 	Accuracy = 1.0
#
# Training with alpha = 0.009000000000000001
# 	Early stopping at epoch 16
# 	Accuracy = 1.0
#
# Training with alpha = 0.010000000000000002
# 	Early stopping at epoch 15
# 	Accuracy = 1.0
#
# Training with alpha = 0.011
# 	Early stopping at epoch 14
# 	Accuracy = 1.0
#
# Training with alpha = 0.012
# 	Early stopping at epoch 13
# 	Accuracy = 1.0
#
# Training with alpha = 0.013000000000000001
# 	Early stopping at epoch 12
# 	Accuracy = 1.0
#
# Training with alpha = 0.014000000000000002
# 	Early stopping at epoch 11
# 	Accuracy = 1.0
#
# Training with alpha = 0.015
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.016
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.017
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.018000000000000002
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.019000000000000003
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.02
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.021
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.022000000000000002
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.023
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.024
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.025
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.026000000000000002
# 	Early stopping at epoch 14
# 	Accuracy = 1.0
#
# Training with alpha = 0.027000000000000003
# 	Early stopping at epoch 14
# 	Accuracy = 1.0
#
# Training with alpha = 0.028
# 	Early stopping at epoch 14
# 	Accuracy = 1.0
#
# Training with alpha = 0.029
# 	Early stopping at epoch 13
# 	Accuracy = 1.0
#
# Training with alpha = 0.030000000000000002
# 	Early stopping at epoch 12
# 	Accuracy = 1.0
#
# Training with alpha = 0.031
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.032
# 	Early stopping at epoch 12
# 	Accuracy = 1.0
#
# Training with alpha = 0.033
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.034
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.035
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.036000000000000004
# 	Early stopping at epoch 12
# 	Accuracy = 1.0
#
# Training with alpha = 0.037000000000000005
# 	Early stopping at epoch 11
# 	Accuracy = 1.0
#
# Training with alpha = 0.038
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.039
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.04
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.041
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.042
# 	Early stopping at epoch 10
# 	Accuracy = 1.0
#
# Training with alpha = 0.043000000000000003
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.044000000000000004
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.045
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.046
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.047
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.048
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.049
# 	Early stopping at epoch 9
# 	Accuracy = 1.0
#
# Training with alpha = 0.05
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.051000000000000004
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.052000000000000005
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.053000000000000005
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.054
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.055
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.056
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.057
# 	Early stopping at epoch 8
# 	Accuracy = 1.0
#
# Training with alpha = 0.058
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.059000000000000004
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.060000000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.061
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.062
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.063
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.064
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.065
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.066
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.067
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.068
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.069
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.07
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.07100000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.07200000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.07300000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.074
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.075
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.076
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.077
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.078
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.079
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.08
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.081
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.082
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.083
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 0.084
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.085
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.08600000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.08700000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.08800000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.089
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.09
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.091
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.092
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.093
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.094
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.095
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.096
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.097
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.098
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.099
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.1
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.101
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.10200000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.10300000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.10400000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.10500000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.106
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 0.107
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.108
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.109
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.11
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.111
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.112
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.113
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.114
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.115
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.116
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.117
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.11800000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.11900000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.12000000000000001
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.121
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.122
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.123
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.124
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.125
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.126
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.127
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.128
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.129
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.13
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.131
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.132
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.133
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.134
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.135
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.136
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.137
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.138
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.139
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.14
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.14100000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.14200000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.14300000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.14400000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.14500000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.146
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.147
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.148
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.149
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.15
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.151
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.152
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.153
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.154
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.155
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.156
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.157
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.158
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.159
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.16
# 	Early stopping at epoch 5
# 	Accuracy = 1.0
#
# Training with alpha = 0.161
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.162
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.163
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.164
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.165
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.166
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.167
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.168
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.169
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.17
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.171
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.17200000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.17300000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.17400000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.17500000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.17600000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.177
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.178
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.179
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.18
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.181
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.182
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.183
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.184
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.185
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.186
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.187
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.188
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.189
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.19
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.191
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.192
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.193
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.194
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.195
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.196
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.197
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.198
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.199
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.2
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.201
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.202
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.203
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.20400000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.20500000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.20600000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.20700000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.20800000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.20900000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.21
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.211
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.212
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.213
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.214
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.215
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.216
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.217
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.218
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.219
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.22
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.221
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.222
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.223
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.224
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.225
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.226
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.227
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.228
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.229
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.23
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.231
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.232
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.233
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.234
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.23500000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.23600000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.23700000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.23800000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.23900000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.24000000000000002
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.241
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.242
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.243
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.244
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.245
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.246
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.247
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.248
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.249
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.25
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.251
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.252
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.253
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.254
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.255
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.256
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.257
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.258
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.259
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.26
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.261
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.262
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.263
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.264
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.265
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.266
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.267
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.268
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.269
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.27
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.271
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.272
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.273
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.274
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.275
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.276
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.277
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.278
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.279
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.281
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28200000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28300000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28400000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28500000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28600000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28700000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28800000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.28900000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.29
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.291
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.292
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.293
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.294
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.295
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.296
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.297
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.298
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.299
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.3
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.301
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.302
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.303
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.304
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.305
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.306
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.307
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.308
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.309
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.31
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.311
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.312
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.313
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.314
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.315
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.316
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.317
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.318
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.319
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.32
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.321
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.322
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.323
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.324
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.325
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.326
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.327
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.328
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.329
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.33
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.331
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.332
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.333
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.334
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.335
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.336
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.337
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.338
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.339
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.341
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.342
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.343
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34400000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34500000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34600000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34700000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34800000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.34900000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.35000000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.35100000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.35200000000000004
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.353
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.354
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.355
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.356
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.357
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.358
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.359
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.36
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.361
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.362
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.363
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.364
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.365
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.366
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.367
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.368
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.369
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.37
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.371
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.372
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.373
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.374
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.375
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.376
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.377
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.378
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.379
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.38
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.381
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.382
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.383
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.384
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.385
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.386
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.387
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.388
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.389
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.39
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.391
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.392
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.393
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.394
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.395
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.396
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.397
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.398
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.399
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.4
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.401
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.402
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.403
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.404
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.405
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.406
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.40700000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.40800000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.40900000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41000000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41100000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41200000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41300000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41400000000000003
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41500000000000004
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41600000000000004
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.41700000000000004
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.418
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.419
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.42
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.421
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.422
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.423
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.424
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.425
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.426
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.427
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.428
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.429
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.43
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.431
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.432
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.433
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.434
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.435
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.436
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.437
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.438
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.439
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.44
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.441
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.442
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.443
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.444
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.445
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.446
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.447
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.448
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.449
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.45
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.451
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.452
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.453
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.454
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.455
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.456
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.457
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.458
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.459
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.46
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.461
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.462
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.463
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.464
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.465
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.466
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.467
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.468
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.46900000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47000000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47100000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47200000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47300000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47400000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47500000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47600000000000003
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47700000000000004
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47800000000000004
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.47900000000000004
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.48000000000000004
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.481
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.482
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.483
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.484
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.485
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.486
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.487
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.488
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.489
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.49
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.491
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.492
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.493
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.494
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.495
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.496
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.497
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.498
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.499
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.501
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.502
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.503
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.504
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.505
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.506
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.507
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.508
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.509
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.51
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.511
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.512
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.513
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.514
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.515
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.516
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.517
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.518
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.519
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.52
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.521
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.522
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.523
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.524
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.525
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.526
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.527
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.528
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.529
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.53
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.531
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.532
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.533
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.534
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.535
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.536
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.537
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.538
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.539
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.54
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.541
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.542
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.543
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.544
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.545
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.546
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.547
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.548
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.549
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.55
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.551
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.552
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.553
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.554
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.555
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.556
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.557
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.558
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.559
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.56
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.561
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.562
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5630000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5640000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5650000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5660000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5670000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5680000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5690000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5700000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5710000000000001
# 	Early stopping at epoch 4
# 	Accuracy = 1.0
#
# Training with alpha = 0.5720000000000001
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.5730000000000001
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.5740000000000001
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.5750000000000001
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.5760000000000001
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.5770000000000001
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.578
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.579
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.58
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.581
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.582
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.583
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.584
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.585
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.586
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.587
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.588
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.589
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.59
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.591
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.592
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.593
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.594
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.595
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.596
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.597
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.598
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.599
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.6
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.601
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.602
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.603
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.604
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.605
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.606
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.607
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.608
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.609
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.61
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.611
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.612
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.613
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.614
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.615
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.616
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.617
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.618
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.619
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.62
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.621
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.622
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.623
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.624
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.625
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.626
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.627
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.628
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.629
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.63
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.631
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.632
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.633
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.634
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.635
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.636
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.637
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.638
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.639
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.64
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.641
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.642
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.643
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.644
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.645
# 	Early stopping at epoch 3
# 	Accuracy = 1.0
#
# Training with alpha = 0.646
# 	Early stopping at epoch 3
# ...
#
# Training with alpha = 4.795000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.796
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.797000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.798
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.799
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.800000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.801
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8020000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.803000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.804
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.805000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.806
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.807
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.808000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.809
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8100000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.811000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.812
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.813000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.814
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.815
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.816000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.817
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8180000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.819000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.82
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.821000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.822
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.823
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.824000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.825
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8260000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.827000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.828
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.829000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.83
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.831
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.832000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.833
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8340000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.835000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.836
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.837000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.838
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.839
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.840000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.841
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8420000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.843000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.844
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.845000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.846
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.847
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.848000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.849
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8500000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.851000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.852
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.853000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.854
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.855
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.856000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.857
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8580000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.859000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.86
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.861000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.862
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.863
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.864000000000001
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.865
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.8660000000000005
# 	Early stopping at epoch 6
# 	Accuracy = 1.0
#
# Training with alpha = 4.867
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.868
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.869000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.87
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.871
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.872000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.873
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.8740000000000006
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.875
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.876
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.877000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.878
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.8790000000000004
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.880000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.881
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.882000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.883
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.884
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.885000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.886
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.8870000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.888000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.889
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.890000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.891
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.892
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.893000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.894
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.8950000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.896000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.897
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.898000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.899
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.901000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.902
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9030000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.904000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.905
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.906000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.907
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.908
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.909000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.91
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9110000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.912000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.913
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.914000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.915
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.916
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.917000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.918
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9190000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.920000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.921
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.922000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.923
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.924
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.925000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.926
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9270000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.928000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.929
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.930000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.931
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.932
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.933000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.934
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9350000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.936000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.937
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.938000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.939
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.94
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.941000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.942
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9430000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.944000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.945
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.946000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.947
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.948
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.949000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.95
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9510000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.952000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.953
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.954000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.955
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.956
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.957000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.958
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9590000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.960000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.961
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.962000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.963
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.964
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.965000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.966
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9670000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.968000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.969
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.970000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.971
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.972
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.973000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.974
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9750000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.976000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.977
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.978000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.979
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.98
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.981000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.982
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9830000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.984000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.985
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.986000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.987
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.988
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.989000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.99
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9910000000000005
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.992000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.993
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.994000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.995
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.996
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.997000000000001
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.998
# 	Early stopping at epoch 7
# 	Accuracy = 1.0
#
# Training with alpha = 4.9990000000000006
# 	Early stopping at epoch 7
# 	Accuracy = 1.0

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey= True)
fig.suptitle('Number of epochs vs. learning rate')
ax1.plot(alphas, num_of_epochs)

ax1.set_title('Full')

ax1.set(xlabel = 'Learning rate', ylabel = 'Number of epochs')
ax1.grid()

ax2.plot(alphas, num_of_epochs)

ax2.set_title('Zoomed in')

ax2.set(xlabel = 'Learning rate', xlim=(-0.01, 0.3))

ax2.grid()

# %% [markdown]
# So as we can see on the graph low learning rate leads to slow learning, while high learning rate leads to fast learning, but with a lot of oscillations. So we need to find a balance between the two.
#
# Since the data set and the problem itself is relatively easy, it is not difficult to find a global minimum. But in real lie problems, picking a learning rate is very important, because if we pick a learning rate that is too high, we might miss the global minimum, and if we pick a learning rate that is too low, we might need a lot of epochs to reach the global minimum.
